# %%
import pandas as pd

# %%
bb = pd.read_html('https://en.wikipedia.org/wiki/List_of_Breaking_Bad_episodes')

# %%
bb[1]
# Out:
#    No.overall  No. inseason                            Title     Directed by  \
# 0           1             1                          "Pilot"  Vince Gilligan
# 1           2             2            "Cat's in the Bag..."  Adam Bernstein
# 2           3             3  "...And the Bag's in the River"  Adam Bernstein
# 3           4             4                     "Cancer Man"       Jim McKay
# 4           5             5                    "Gray Matter"    Tricia Brock
# 5           6             6       "Crazy Handful of Nothin'"  Bronwen Hughes
# 6           7             7     "A No-Rough-Stuff-Type Deal"      Tim Hunter
#
#        Written by  Original air date U.S. viewers(millions)
# 0  Vince Gilligan   January 20, 2008                1.41[4]
# 1  Vince Gilligan   January 27, 2008                1.49[5]
# 2  Vince Gilligan  February 10, 2008                1.08[6]
# 3  Vince Gilligan  February 17, 2008                1.09[7]
# ...
